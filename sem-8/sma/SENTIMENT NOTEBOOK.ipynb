# %%
import pandas as pd

# %%
GB_comments = pd.read_csv("GBcommentsmain.csv", error_bad_lines=False) #Change in the code
# Out:
# C:\Users\Joel Dsouza\AppData\Local\Temp\ipykernel_139196\2552740296.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   GB_comments = pd.read_csv("GBcommentsmain.csv", error_bad_lines=False) #Change in the code
# Skipping line 113225: expected 4 fields, saw 5
#
# Skipping line 158379: expected 4 fields, saw 7
# Skipping line 241590: expected 4 fields, saw 5
# Skipping line 245637: expected 4 fields, saw 7
#
# Skipping line 521402: expected 4 fields, saw 5

# %%
GB_videos = pd.read_csv("GBvideosmain.csv",error_bad_lines=False)
# Out:
# C:\Users\Joel Dsouza\AppData\Local\Temp\ipykernel_139196\1844702410.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   GB_videos = pd.read_csv("GBvideosmain.csv",error_bad_lines=False)
# Skipping line 2398: expected 11 fields, saw 21
# Skipping line 2797: expected 11 fields, saw 21

# %%
GB_comments.head()
# Out:
#       video_id                                       comment_text  likes  \
# 0  jt2OHQh0HoQ  It's more accurate to call it the M+ (1000) be...      0
# 1  jt2OHQh0HoQ              To be there with a samsung phone\n😂😂😂      1
# 2  jt2OHQh0HoQ  Thank gosh, a place I can watch it without hav...      0
# 3  jt2OHQh0HoQ  What happened to the home button on the iPhone...      0
# 4  jt2OHQh0HoQ  Power is the disease.  Care is the cure.  Keep...      0
#
#    replies
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
GB_videos.head()
# Out:
#       video_id                                              title  \
# 0  jt2OHQh0HoQ  Live Apple Event - Apple September Event 2017 ...
# 1  AqokkXoa7uE  Holly and Phillip Meet Samantha the Sex Robot ...
# 2  YPVcg45W0z4                    My DNA Test Results! I'm WHAT?!
# 3  T_PuZBdT2iM  getting into a conversation in a language you ...
# 4  NsjsmgmbCfc                               Baby Name Challenge!
#
#        channel_title  category_id  \
# 0        Apple Event           28
# 1       This Morning           24
# 2       emmablackery           24
# 3              ProZD            1
# 4  Sprinkleofglitter           26
#
#                                                 tags    views  likes  \
# 0  apple events|apple event|iphone 8|iphone x|iph...  7426393  78240
# 1  this morning|interview|holly willoughby|philli...   494203   2651
# 2  emmablackery|emma blackery|emma|blackery|briti...   142819  13119
# 3  skit|korean|language|conversation|esl|japanese...  1580028  65729
# ...

# %%
GB_comments = pd.read_csv("GBCommentsclean.csv", error_bad_lines=False) #Change in the code
# Out:
# C:\Users\Joel Dsouza\AppData\Local\Temp\ipykernel_139196\755315336.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   GB_comments = pd.read_csv("GBCommentsclean.csv", error_bad_lines=False) #Change in the code

# %%
GB_comments.head()
# Out:
#    Unnamed: 0     video_id                                       comment_text  \
# 0           0  jt2OHQh0HoQ  It's more accurate to call it the M+ (1000) be...
# 1           1  jt2OHQh0HoQ              To be there with a samsung phone\n😂😂😂
# 2           2  jt2OHQh0HoQ  Thank gosh, a place I can watch it without hav...
# 3           3  jt2OHQh0HoQ  What happened to the home button on the iPhone...
# 4           4  jt2OHQh0HoQ  Power is the disease.  Care is the cure.  Keep...
#
#    likes  replies
# 0      0        0
# 1      1        0
# 2      0        0
# 3      0        0
# 4      0        0

# %%
GB_comments['comment_text'] = GB_comments['comment_text'].str.replace("[^a-zA-Z#]", " ")
# Out:
# C:\Users\Joel Dsouza\AppData\Local\Temp\ipykernel_139196\2785164002.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   GB_comments['comment_text'] = GB_comments['comment_text'].str.replace("[^a-zA-Z#]", " ")

# %%
GB_comments['comment_text'] = GB_comments['comment_text'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))

# %%
GB_comments['comment_text'] = GB_comments['comment_text'].apply(lambda x:x.lower())

# %%
tokenized_tweet = GB_comments['comment_text'].apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0    [more, accurate, call, because, price, closer,...
# 1                        [there, with, samsung, phone]
# 2    [thank, gosh, place, watch, without, having, s...
# 3    [what, happened, home, button, iphone, cough, ...
# 4    [power, disease, care, cure, keep, caring, you...
# Name: comment_text, dtype: object

# %%
GB_comments = pd.read_csv("GBCommentssentiments.csv", error_bad_lines=False) #Change in the code
# Out:
# C:\Users\Joel Dsouza\AppData\Local\Temp\ipykernel_139196\120904259.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   GB_comments = pd.read_csv("GBCommentssentiments.csv", error_bad_lines=False) #Change in the code

# %%
GB_comments['Sentiment'] = GB_comments['Sentiment Scores'].apply(lambda s : 'Positive' if s > 0 else ('Neutral' if s == 0 else 'Negative'))

# %%
GB_comments.head()
# Out:
#    Unnamed: 0     video_id                                       comment_text  \
# 0           0  jt2OHQh0HoQ  more accurate call because price closer than c...
# 1           1  jt2OHQh0HoQ                           there with samsung phone
# 2           2  jt2OHQh0HoQ  thank gosh place watch without having speed do...
# 3           3  jt2OHQh0HoQ  what happened home button iphone cough copying...
# 4           4  jt2OHQh0HoQ  power disease care cure keep caring yourself o...
#
#    likes  replies  Sentiment Scores Sentiment
# 0      0        0            0.0000   Neutral
# 1      1        0            0.0000   Neutral
# 2      0        0            0.6369  Positive
# 3      0        0            0.0000   Neutral
# 4      0        0            0.8910  Positive

# %%
GB_comments.Sentiment.value_counts()
# Out:
# Positive    331817
# Neutral     267098
# Negative    119508
# Name: Sentiment, dtype: int64

# %%
all_words = ' '.join([str(text) for text in GB_comments['comment_text']])

# %%
import matplotlib.pyplot as plt 
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
all_words_posi = ' '.join([text for text in GB_comments['comment_text'][GB_comments.Sentiment == 'Positive']])

# %%
wordcloud_posi = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words_posi)      
plt.figure(figsize=(10, 7))                    
plt.imshow(wordcloud_posi, interpolation="bilinear")                     
plt.axis('off')             
plt.show()

# %%
all_words_nega = ' '.join([text for text in GB_comments['comment_text'][GB_comments.Sentiment == 'Negative']])

# %%
wordcloud_nega = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words_nega)      
plt.figure(figsize=(10, 7))                    
plt.imshow(wordcloud_nega, interpolation="bilinear")                     
plt.axis('off')             
plt.show()
