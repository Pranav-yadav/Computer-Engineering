# %%
# !pip install wordcloud
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: wordcloud in c:\users\swastik\anaconda3\lib\site-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in c:\users\swastik\anaconda3\lib\site-packages (from wordcloud) (3.7.0)
# Requirement already satisfied: pillow in c:\users\swastik\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\swastik\anaconda3\lib\site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\swastik\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\swastik\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\swastik\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\swastik\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\swastik\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\swastik\anaconda3\lib\site-packages (from matplotlib->wordcloud) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\swastik\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\swastik\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
GB_comments = pd.read_csv("C:/Users/Swastik/OneDrive/Desktop/SMA-pracc-final/SMA_datasets/SMA-REAL-DATASETS/Amazon Reviewer Dataset/amazonsentiments.csv")

# %%
GB_comments['Sentiment'] = GB_comments['Sentiment Scores'].apply(lambda s : 'Positive' if s > 0 else ('Neutral' if s == 0 else 'Negative'))

# %%
GB_comments.Sentiment.value_counts()
# Out:
# Positive    60
# Neutral     14
# Negative     6
# Name: Sentiment, dtype: int64

# %%
all_words = ' '.join([str(text) for text in GB_comments['reviewDescription']])          
from wordcloud import WordCloud     
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)     
plt.figure(figsize=(10, 7))       
plt.imshow(wordcloud, interpolation="bilinear")          
plt.axis('off')            
plt.show()

# %%
all_words_posi = ' '.join([text for text in GB_comments['reviewDescription'][GB_comments.Sentiment == 'Positive']])

# %%
wordcloud_posi = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words_posi)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud_posi, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
all_words_posi = ' '.join([text for text in GB_comments['reviewDescription'][GB_comments.Sentiment == 'Negative']]) 
wordcloud_posi = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words_posi)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud_posi, interpolation="bilinear")
plt.axis('off')
plt.show()
