# %%
# !pip install scipy

# %%
# !pip install networkx

# %%
import pandas as pd         
import networkx as nx

# %%
df=pd.read_csv("C:/Users/Swastik/OneDrive/Desktop/SMA-pracc-final/SMA_datasets/SMA-REAL-DATASETS/Networks/new_public_figure_edges.csv")        
df.head()
# Out:
#    node_1  node_2
# 0       0    1490
# 1       0    2742
# 2       0    7265
# 3       0    8076
# 4       0    8844

# %%
fb_graph = nx.from_pandas_edgelist(df,source="node_1", target="node_2")           
type(fb_graph)
# Out:
# networkx.classes.graph.Graph

# %%
fb_graph.nodes()
# Out:
# NodeView((0, 1490, 2742, 7265, 8076, 8844, 4577, 1099, 9669, 2535, 9060, 2260, 4086, 710, 10886, 8150, 2954, 469, 6012, 6469, 122, 9104, 7372, 1, 8431, 999, 4827, 7763, 5080, 5363, 567, 3460, 3980, 6774, 4388, 5594, 1067, 162, 6937, 7300, 7498, 2622, 415, 10697, 2, 6187, 10813, 2830, 9340, 8786, 5303, 8605, 3903, 6747, 535, 7477, 5722, 1265, 7292, 10139, 4080, 9891, 6934, 10219, 4799, 2663, 6399, 4262, 2278, 5073, 6156, 550, 9717, 1970, 2129, 3740, 8436, 6322, 6582, 11024, 8016, 8669, 9100, 6952, 1808, 4093, 6222, 749, 6603, 5487, 2469, 8826, 3084, 5880, 3397, 2150, 3582, 5664, 3108, 6232, 52, 5269, 940, 3760, 6297, 1493, 57, 4999, 6327, 3070, 1134, 6974, 1684, 4128, 7778, 733, 9214, 9887, 9948, 6978, 6980, 8382, 5696, 6451, 4855, 7312, 7681, 5706, 11060, 3403, 4862, 6276, 7326, 1522, 3270, 11411, 8687, 79, 6641, 6007, 8787, 621, 5840, 1700, 1358, 881, 1536, 7012, 7933, 1868, 5733, 7195, 1175, 9429, 1710, 6485, 7204, 2755, 2212, 2213, 1011, 1376, 3645, 330, 6692, 6115, 4353, 1381, 10
# ...

# %%
fb_graph.edges()
# Out:
# EdgeView([(0, 1490), (0, 2742), (0, 7265), (0, 8076), (0, 8844), (0, 4577), (0, 1099), (0, 9669), (0, 2535), (0, 9060), (0, 2260), (0, 4086), (0, 710), (0, 10886), (0, 8150), (0, 2954), (0, 469), (0, 6012), (0, 6469), (0, 122), (0, 9104), (0, 7372), (7265, 8266), (7265, 381), (8076, 459), (4577, 122), (4577, 146), (2535, 184), (4086, 122), (4086, 188), (710, 122), (10886, 469), (2954, 459), (2954, 569), (469, 122), (469, 6012), (469, 9104), (469, 5023), (122, 5235), (122, 3851), (122, 6967), (122, 6618), (122, 3409), (122, 8224), (122, 3736), (122, 9306), (122, 840), (122, 8488), (122, 5052), (122, 11333), (122, 10107), (122, 4641), (122, 8686), (122, 10720), (122, 5023), (9104, 146), (9104, 290), (7372, 459), (7372, 569), (1, 8431), (1, 999), (1, 4827), (999, 262), (999, 340), (999, 381), (999, 481), (4827, 585), (7763, 5080), (7763, 5363), (7763, 567), (7763, 3460), (7763, 3980), (7763, 6774), (7763, 4388), (7763, 5594), (7763, 1067), (7763, 162), (7763, 6937), (7763, 7300), (7763,
# ...

# %%
fb_graph.add_edge("123","2154")        
fb_graph.nodes()
# Out:
# NodeView((0, 1490, 2742, 7265, 8076, 8844, 4577, 1099, 9669, 2535, 9060, 2260, 4086, 710, 10886, 8150, 2954, 469, 6012, 6469, 122, 9104, 7372, 1, 8431, 999, 4827, 7763, 5080, 5363, 567, 3460, 3980, 6774, 4388, 5594, 1067, 162, 6937, 7300, 7498, 2622, 415, 10697, 2, 6187, 10813, 2830, 9340, 8786, 5303, 8605, 3903, 6747, 535, 7477, 5722, 1265, 7292, 10139, 4080, 9891, 6934, 10219, 4799, 2663, 6399, 4262, 2278, 5073, 6156, 550, 9717, 1970, 2129, 3740, 8436, 6322, 6582, 11024, 8016, 8669, 9100, 6952, 1808, 4093, 6222, 749, 6603, 5487, 2469, 8826, 3084, 5880, 3397, 2150, 3582, 5664, 3108, 6232, 52, 5269, 940, 3760, 6297, 1493, 57, 4999, 6327, 3070, 1134, 6974, 1684, 4128, 7778, 733, 9214, 9887, 9948, 6978, 6980, 8382, 5696, 6451, 4855, 7312, 7681, 5706, 11060, 3403, 4862, 6276, 7326, 1522, 3270, 11411, 8687, 79, 6641, 6007, 8787, 621, 5840, 1700, 1358, 881, 1536, 7012, 7933, 1868, 5733, 7195, 1175, 9429, 1710, 6485, 7204, 2755, 2212, 2213, 1011, 1376, 3645, 330, 6692, 6115, 4353, 1381, 10
# ...

# %%
import matplotlib.pyplot as plt            
# %matplotlib inline

# %%
G = nx.Graph(fb_graph)                  
nx.graph
# Out:
# <module 'networkx.classes.graph' from 'C:\\Users\\Swastik\\anaconda3\\lib\\site-packages\\networkx\\classes\\graph.py'>

# %%
# nx.draw(fb_graph, with_labels = True)

# nx.draw_networkx(fb_graph, with_labels=True, node_color='blue') 

# nx.draw_networkx(nx.relabel_nodes(fb_graph, nx.get_node_attributes(fb_graph,'node_1')), with_labels=True, node_color = 'orange')

# %%
nx.degree(fb_graph)
nx.degree(fb_graph,519)
nx.degree_centrality(fb_graph)
# Out:
# {0: 0.0048597305058537665,
#  1490: 0.0002208968411751712,
#  2742: 0.0002208968411751712,
#  7265: 0.0006626905235255136,
#  8076: 0.0004417936823503424,
#  8844: 0.0002208968411751712,
#  4577: 0.0006626905235255136,
#  1099: 0.0002208968411751712,
#  9669: 0.0002208968411751712,
#  2535: 0.0004417936823503424,
#  9060: 0.0002208968411751712,
#  2260: 0.0002208968411751712,
#  4086: 0.0006626905235255136,
#  710: 0.0004417936823503424,
#  10886: 0.0004417936823503424,
#  8150: 0.0002208968411751712,
#  2954: 0.0006626905235255136,
#  469: 0.0013253810470510272,
#  6012: 0.0004417936823503424,
#  6469: 0.0002208968411751712,
#  122: 0.0048597305058537665,
#  9104: 0.0008835873647006848,
#  7372: 0.0006626905235255136,
#  1: 0.0006626905235255136,
#  8431: 0.0002208968411751712,
#  999: 0.001104484205875856,
#  4827: 0.0004417936823503424,
#  7763: 0.0035343494588027393,
#  5080: 0.0002208968411751712,
#  5363: 0.0002208968411751712,
#  567: 0.003313452617627568,
# ...

# %%
sorted(nx.degree_centrality(fb_graph).values())        
m_influential=nx.degree_centrality(G)           
for w in sorted(m_influential,key=m_influential.get,reverse=True):
    print(w,m_influential[w])
# Out:
# 5638 0.056991385023194174
# 98 0.04859730505853767
# 2 0.04572564612326044
# 491 0.042853987187983215
# 3740 0.039761431411530816
# 57 0.03931963772918048
# 381 0.035122597746852224
# 184 0.033576319858626025
# 459 0.03313452617627568
# 237 0.02739120830572123
# 79 0.026507620941020545
# 330 0.025403136735144688
# 262 0.023856858846918492
# 31 0.02208968411751712
# 290 0.019438922023415066
# 455 0.019218025182239896
# 535 0.018997128341064724
# 501 0.017450850452838524
# 401 0.017009056770488182
# 370 0.01634636624696267
# 206 0.016125469405787497
# 392 0.015020985199911642
# 65 0.01480008835873647
# 105 0.014358294676386128
# 511 0.014358294676386128
# 35 0.013695604152860615
# 100 0.013695604152860615
# 172 0.01281201678815993
# 14 0.011486635741108902
# 24 0.01104484205875856
# 565 0.010161254694057875
# 55 0.009940357852882704
# 288 0.009498564170532362
# 9662 0.009498564170532362
# 341 0.009498564170532362
# 43 0.00927766732935719
# 82 0.008835873647006848
# ...

# %%
pos=nx.spring_layout(G) 
betCent=nx.betweenness_centrality(G,normalized=True,endpoints=True)          
node_color=[20000.0*G.degree(v)for v in G]              
node_size=[v*10000 for v in betCent.values()]                
plt.figure(figsize=(20,20))                              
nx.draw_networkx(G,pos = pos,with_labels=False,node_color=node_color,node_size=node_size)                     
sorted(betCent,key=betCent.get,reverse=True)[:5]
# Out:
# [2, 57, 98, 5638, 381]

# %%
 #closeness centrality       
closeness_centrality=nx.centrality.closeness_centrality(G)                       
sorted(closeness_centrality.items(),key=lambda item:item[1],reverse=True)[:8]
# Out:
# [(2, 0.2803706646439722),
#  (57, 0.27108115709180924),
#  (381, 0.26985505764076423),
#  (1011, 0.2618029456123286),
#  (459, 0.261361843466466),
#  (6978, 0.25905725005714253),
#  (98, 0.25867709667525496),
#  (290, 0.2555071177596141)]

# %%
node_size=[v*50 for v in closeness_centrality.values()]        
plt.figure(figsize=(15,8))                   
nx.draw_networkx(G,pos=pos,node_size=node_size,with_labels=False,width=0.15)                
plt.axis("off")
# Out:
# (-39.87840923121411,
#  813.2662134276587,
#  -20.585665760972994,
#  409.40441535047376)

# %%
nx.has_bridges(G)
# Out:
# True

# %%
bridges=list(nx.bridges(G))               
len(bridges)
# Out:
# 2520

# %%
plt.figure(figsize=(15,5))     
nx.draw_networkx(G,pos=pos,node_size=10,with_labels=False,width=0.15)          
nx.draw_networkx_edges(G,pos,edgelist=bridges,width=0.5,edge_color="green")                 
nx.draw_networkx_edges(G,pos,edgelist=bridges,width=0.5,edge_color="blue")              
plt.axis("off")
# Out:
# (-39.87840923121411, 813.2662134276587, -13.294423597218406, 256.2883299116274)

# %%
nx_av
